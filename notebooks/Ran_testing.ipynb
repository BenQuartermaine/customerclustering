# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import customerclustering
from customerclustering.practice import *
from customerclustering.queue import *
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.13/envs/customerclustering/lib/python3.8/site-packages/pymysql/connections.py:613, in Connection.connect(self, sock)
#     612 try:
# --> 613     sock = socket.create_connection(
#     614         (self.host, self.port), self.connect_timeout, **kwargs
#     615     )
#     616     break
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/socket.py:808, in create_connection(address, timeout, source_address)
#     807 try:
# --> 808     raise err
#     809 finally:
#     810     # Break explicitly a reference cycle
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/socket.py:796, in create_connection(address, timeout, source_address)
#     795     sock.bind(source_address)
# --> 796 sock.connect(sa)
#     797 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import customerclustering
#       2 from customerclustering.practice import *
# ----> 3 from customerclustering.queue import *
#
# File ~/code/Ricotta-md/customerclustering/customerclustering/queue.py:9, in <module>
#       6 import datetime as dt
#       7 import numpy as np
# ----> 9 conn = pymysql.connect(
#      10     host=os.getenv('HOST'),
#      11     port=int(3306),
#      12     user=os.getenv('USER_DB'),
#      13     passwd=os.getenv('PASSWORD'),
#      14     db=os.getenv('DB'),
#      15     charset='utf8mb4')
#      17 class Queue:
#      18     def __init__(self, df):
#      19         # Import data only once
#
# File ~/.pyenv/versions/3.8.13/envs/customerclustering/lib/python3.8/site-packages/pymysql/connections.py:353, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351     self._sock = None
#     352 else:
# --> 353     self.connect()
#
# File ~/.pyenv/versions/3.8.13/envs/customerclustering/lib/python3.8/site-packages/pymysql/connections.py:664, in Connection.connect(self, sock)
#     662     if DEBUG:
#     663         print(exc.traceback)
# --> 664     raise exc
#     666 # If e is neither DatabaseError or IOError, It's a bug.
#     667 # But raising AssertionError hides original error.
#     668 # So just reraise it.
#     669 raise
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([Errno 61] Connection refused)")

# %%
queue=Queue()
queue.get_queue_features()
