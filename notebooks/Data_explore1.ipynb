# %%
import os
import pymysql
import pandas as pd
from dotenv import load_dotenv, find_dotenv

# %%
env_path = find_dotenv()
load_dotenv(env_path)
# Out:
# True

# %%
import os
import pymysql
import pandas as pd


conn = pymysql.connect(
    host=os.getenv('HOST'),
    port=int(3306),
    user=os.getenv('USER_DB'),
    passwd=os.getenv('PASSWORD_DB'),
    db=os.getenv('DB'),
    charset='utf8mb4')

df = pd.read_sql_query("SELECT * FROM category LIMIT 100;", conn)
# Out:
# /Users/jebzhang/.pyenv/versions/3.8.13/envs/customerclustering/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df.metaTitle
# Out:
# 0                              Paediatrics CPD | Ausmed
# 1                 PCAs and AINs Online CPD Hub | Ausmed
# 2     Mandatory Training Resources for Health and Ag...
# 3                         Wound Management CPD | Ausmed
# 4                           Mental Health CPD | Ausmed
# 5                              Medications CPD | Ausmed
# 6                Healthcare Law and Ethics CPD | Ausmed
# 7             COVID-19 (Coronavirus) Resources | Ausmed
# 8     Infection Prevention, Control and Disease CPD ...
# 9                         Drug and Alcohol CPD | Ausmed
# 10                         Chronic Disease CPD | Ausmed
# 11            Clinical Assessment and Care CPD | Ausmed
# 12           Primary and Preventive Health CPD | Ausmed
# 13               Prehospital and Paramedic CPD | Ausmed
# 14                      Aged Care CPD | Ausmed Learning
# 15     Disability, Community and Home Care CPD | Ausmed
# 16           Self-Care and Wellbeing Resources | Ausmed
# ...

# %%
#number of valid comments

# %%
import os
import pymysql
import pandas as pd

conn = pymysql.connect(
    host='aurora-staging-instance-1-ap-southeast-2a.cnhyotkoyfuh.ap-southeast-2.rds.amazonaws.com',
    port=int(3306),
    user="bootcamps",
    passwd='as7ByViutv_7iYpko*',
    db="account_shaped",
    charset='utf8mb4')

df1 = pd.read_sql_query("SELECT count(*) FROM comment where content is not null;", conn)
# Out:
# /Users/jebzhang/.pyenv/versions/3.8.13/envs/customerclustering/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df1
# Out:
#    count(*)
# 0    355554

# %%
#comment update date

# %%
import os
import pymysql
import pandas as pd

conn = pymysql.connect(
    host='aurora-staging-instance-1-ap-southeast-2a.cnhyotkoyfuh.ap-southeast-2.rds.amazonaws.com',
    port=int(3306),
    user="bootcamps",
    passwd='as7ByViutv_7iYpko*',
    db="account_shaped",
    charset='utf8mb4')

df2 = pd.read_sql_query("SELECT * FROM comment where content is not null;", conn)
# Out:
# /Users/jebzhang/.pyenv/versions/3.8.13/envs/customerclustering/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
from datetime import datetime

def date_convert(date_to_convert):
    return datetime.strptime(str(date_to_convert), "%Y-%m-%d %H:%M:%S").month

df2['month']= df2['updateDate'].apply(date_convert)

# %%
df2['count'] =1
comment_count_df = df2[['month','count']]
comment_count_df
# Out:
#         month  count
# 0           5      1
# 1          11      1
# 2           5      1
# 3           7      1
# 4          11      1
# ...       ...    ...
# 355549      5      1
# 355550      9      1
# 355551      3      1
# 355552      4      1
# 355553      5      1
#
# [355554 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# plt.plot(comment_count_df['month'])

df2['month'].value_counts()
#45% of the comments  were made in Apr and May month, with May contributing to 28%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#       4 # plt.plot(comment_count_df['month'])
#       6 df2['month'].value_counts()
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import os
import pymysql
import pandas as pd

conn = pymysql.connect(
    host='aurora-staging-instance-1-ap-southeast-2a.cnhyotkoyfuh.ap-southeast-2.rds.amazonaws.com',
    port=int(3306),
    user="bootcamps",
    passwd='as7ByViutv_7iYpko*',
    db="account_shaped",
    charset='utf8mb4')

df3 = pd.read_sql_query("SELECT * FROM goal;", conn)
# Out:
# /Users/jebzhang/.pyenv/versions/3.8.13/envs/customerclustering/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df3
# Out:
#                                       goalID  \
# 0       00005d58-bb42-4b39-b412-a665efbbb512
# 1       00015df6-b936-4f1b-8d9c-1b4759f78ba7
# 2       0001ddc3-f649-4a15-9bfb-81a00146d0b3
# 3       00028225-a41b-407e-af66-b3660b92d8ce
# 4       00030114-1484-4004-a148-74a1536767b2
# ...                                      ...
# 122581  fffd4793-5e4d-40a7-aeb2-a4b972422455
# 122582  fffdd38b-ba75-4061-8b53-f754d2a4d01f
# 122583  fffe1d30-4348-4177-9df6-288d0315bc3e
# 122584  fffe87cf-8f57-421a-906f-46f82dc1afc9
# 122585  ffff10a8-85b0-48d7-bcc3-9c10d0b33ce9
#
#                                        owner  \
# 0       e970fb89-6e51-4da5-a578-45c64e3c04fd
# 1       9629fc28-f907-4273-9a70-46777969bdb8
# 2       567120d7-eee6-4a3b-87f8-aaaa38f8b4e4
# 3       5ec5104d-513b-4cfb-9a7b-fd62bd74d2dd
# 4       0f88ad4e-35fe-4f2f-a237-f292dd805d16
# ...                                      ...
# 122581  31656c23-c81f-4ec3-8e71-e874420c4a08
# 122582  39dced49-ed52-4fa6-8ca5-72eeb3e75385
# ...

# %%
import os
import pymysql
import pandas as pd

conn = pymysql.connect(
    host='aurora-staging-instance-1-ap-southeast-2a.cnhyotkoyfuh.ap-southeast-2.rds.amazonaws.com',
    port=int(3306),
    user="bootcamps",
    passwd='as7ByViutv_7iYpko*',
    db="account_shaped",
    charset='utf8mb4')

df4 = pd.read_sql_query("SELECT * FROM resource;", conn)

# %%
df4['activityType'].value_counts()

# %%
fig, ax = plt.subplots()
sns.histplot(df4['min'], kde = True, ax = ax)
ax.set_xlim(0,1000)
plt.show()

# %%
fig, ax = plt.subplots()
sns.histplot(df4['min'], kde = True, ax = ax)
ax.set_xlim(0,100)
plt.show()

# %%
import os
import pymysql
import pandas as pd

conn = pymysql.connect(
    host='aurora-staging-instance-1-ap-southeast-2a.cnhyotkoyfuh.ap-southeast-2.rds.amazonaws.com',
    port=int(3306),
    user="bootcamps",
    passwd='as7ByViutv_7iYpko*',
    db="account_shaped",
    charset='utf8mb4')

df5 = pd.read_sql_query("SELECT * FROM tracking_event;", conn)

# %%
df5

# %%
df5['eventType'].value_counts().head(20)

# %%
from datetime import datetime

def date_convert(date_to_convert):
    return datetime.strptime(str(date_to_convert), "%Y-%m-%d %H:%M:%S").month

df5['month']= df5['eventDate'].apply(date_convert)

# %%
df5[df5['eventType'] == "course_completed"].count()

# %%
#39% of courses week completed in April and May

df5[df5['eventType'] == "course_completed"]['month'].value_counts()

# %%
df5[df5['eventType'] == "course_queued"]['month'].value_counts()

# %%
import os
import pymysql
import pandas as pd

conn = pymysql.connect(
    host=os.getenv('HOST'),
    port=int(3306),
    user=os.getenv('USER_DB'),
    passwd=os.getenv('PASSWORD_DB'),
    db=os.getenv('DB'),
    charset='utf8mb4')

user_df = pd.read_sql_query("""select *
                            FROM user
                                ;""", conn)
# Out:
# /Users/jebzhang/.pyenv/versions/3.8.13/envs/customerclustering/lib/python3.8/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
user_df[user_df['stripeCustID']=='cus_KEaTUNnv66lLey']
# Out:
#                                       userID dateOfBirth postalAddress  \
# 136287  715df8a1-65fc-4ee5-bd1e-9ce17302fedb        None          None
#
#        billingAddress gender            timezone        stripeCustID  \
# 136287           None   None  Australia/Brisbane  cus_KEaTUNnv66lLey
#
#        adminGroup          createDate
# 136287       None 2021-09-15 23:13:22

# %%
len(user_df.stripeCustID.unique())
# Out:
# 212725

# %%
user_df.sort_values(by ='createDate')
# Out:
#                                       userID dateOfBirth  \
# 25365   150bc40f-2a44-435f-8f9a-f50d113aa0fa        None
# 288274  efc89e46-2f3d-4d6d-b938-f37b5b30c3fa        None
# 167924  8b89cdc6-3f3a-43f0-b490-9de9731860e9        None
# 19829   10675105-7da0-4d8b-b58c-078f67fc0010        None
# 65268   3639f037-5f38-4a12-91d8-82c87696f808        None
# ...                                      ...         ...
# 307564  ffdc2add-db25-418a-9ba0-6b0e6c9d418f        None
# 307605  ffe44ce4-b0e4-4cff-9c15-c8028ffca761        None
# 307646  ffed1713-ec48-4c0e-87c8-2cc036b6e5b8        None
# 307683  fff383a6-c47a-4e79-a38d-3808674ec113        None
# 307699  fff61bc7-77ae-49c4-8e22-037b983f7d3f        None
#
#                                postalAddress  \
# 25365                                   None
# 288274  f584b45d-3851-40cb-920a-294c9fa0b410
# 167924                                  None
# 19829   cc93fdab-5b44-4de2-87d6-f89e9c3ced89
# 65268                                   None
# ...
